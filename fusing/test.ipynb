# %%
import json

# %%
NODE_PATH_FILE = r'E:\meituan_project\knowledge\process\node_path_new.json'
with open(NODE_PATH_FILE, 'r', encoding='utf-8') as f:
    NODE_PATH = json.load(f)

# %%
# print(NODE_PATH)

# %%
zuo = set()
you = set()
for key in NODE_PATH:
    # print(key)
    # print(NODE_PATH[key])
    zuo.add(key)
    you.add(NODE_PATH[key])

# %% [markdown]
# ### 融合前后的叶子节点总数

# %%
print(len(zuo))
print(len(you))
# Out:
# 510
# 429

# %%
ORIGIN_NODE_PATH_FILE = r'C:\Users\humingwang\Desktop\融合节点数据\node_path.json'
with open(ORIGIN_NODE_PATH_FILE, 'r', encoding='utf-8') as f:
    ORIGIN_NODE_PATH = json.load(f)
origin_zuo = set()
origin_you = set()
for key in ORIGIN_NODE_PATH:
    # print(key)
    # print(NODE_PATH[key])
    origin_zuo.add(key)
    origin_you.add(ORIGIN_NODE_PATH[key])
print(len(origin_zuo))
print(len(origin_you))
# Out:
# 516
# 516

# %%
# 加载已经标记好的结构树
TREE_FILE = r'.\输入输出\tree.json'
with open(TREE_FILE, 'r', encoding='utf-8') as f:
    INFOS = json.load(f)

# %%
# print(INFOS)

# %%
for key in INFOS:
    print(key)
# Out:
# 食材树

# %%
tree = INFOS['食材树']

# %%
print(tree)
# Out:
# {'谷类及制品': {'小麦': {'面粉': {'小麦粉': {}}, '面条': {'辣椒面': {}, '意面': {}, '面条类': {}}, '馒头、花卷': {'馒头': {}}, '饼干': {'奥利奥饼干': {}}, '面饼': {}, '面包': {}, '面皮': {}, '面包糠': {}, '油条': {}, '凉皮': {}, '饺子': {}, '面筋': {}, '锅贴': {}, '包子': {}}, '稻米': {'米饭、米粥等': {'米饭': {}, '寿司': {}}, '米粉': {}, '爆米花': {}, '年糕': {}, '糍粑': {}, '锅巴': {}, '麻团': {}, '米线': {}, '黑米': {}, '河粉': {}, '大米': {'糯米': {}}}, '玉米': {'玉米': {'芝士玉米': {}}, '玉米面、玉米粒等': {'玉米粒': {}}}, '大麦': {'大麦面粉': {}, '大麦制品': {}}, '小米、黄米': {'小米、黄米': {}, '小米或黄米制品': {}}, '燕麦及制品': {}, '高粱及制品': {}, '糜子及制品': {}, '莜麦及制品': {}, '麦谷制品': {}, '薏米及制品': {}}, '薯类、淀粉及制品': {'薯类': {'马铃薯': {'土豆粉': {}, '土豆': {}, '薯片': {}, '薯条': {}}, '甘薯': {}, '木薯': {}, '红薯': {'地瓜': {}}, '紫薯': {}, '香芋': {}, '薯类制品': {'芋圆': {}, '珍珠': {}}}, '淀粉类': {'食用淀粉': {}, '淀粉制品': {'粉丝': {}, '粉条': {}, '藕粉': {}, '西谷米': {}, '粉皮': {}, '宽粉': {}, '粉': {}, '凉粉': {}}}}, '干豆类及制品': {'大豆': {'大豆': {'青豆': {}, '毛豆': {}, '黄豆': {}}, '豆腐、豆干制品': {'血豆腐': {}, '豆腐': {}, '干豆腐': {}, '冻豆腐': {}, '豆腐干': {}, '千页豆腐': {}, '豆腐泡': {}}, '豆浆类制品': 
# ...

# %%
big_class = set()
for key in tree:
    big_class.add(key)

# %%
print(big_class)
# Out:
# {'饮料和冷饮类', '蔬菜类及制品', '其他', '乳类及制品', '水果类及制品', '坚果、种子类', '肉类及制品', '舍弃类', '调味品类', '蛋类及制品', '含酒精饮料', '油脂类', '薯类、淀粉及制品', '休闲食品', '谷类及制品', '干豆类及制品', '速食食品', '菌藻类'}

# %% [markdown]
# ### 现阶段的大类总数

# %%
print(len(big_class))
# Out:
# 18

# %%
for key in big_class:
    print(key)
    # print(tree[key])
    if tree[key] == '{}':
        print(tree[key])
# Out:
# 饮料和冷饮类
# 蔬菜类及制品
# 其他
# 乳类及制品
# 水果类及制品
# 坚果、种子类
# 肉类及制品
# 舍弃类
# 调味品类
# 蛋类及制品
# 含酒精饮料
# 油脂类
# 薯类、淀粉及制品
# 休闲食品
# 谷类及制品
# 干豆类及制品
# 速食食品
# 菌藻类

# %%
origin_path = r'C:\Users\humingwang\Desktop\融合节点数据\tree.json'

# %%
# 加载已经标记好的结构树
ORIGIN_TREE_FILE = origin_path
with open(ORIGIN_TREE_FILE, 'r', encoding='utf-8') as f:
    ORIGIN_INFOS = json.load(f)

# %%
print(ORIGIN_INFOS)
# Out:
# {'食材树': {'谷类及制品': {'小麦': {'面粉': {'小麦粉': {}}, '面条': {'面条类': {}, '意面': {}, '辣椒面': {}, '意大利面': {}}, '馒头、花卷': {'馒头': {}}, '面饼': {'饼干': {}}, '其他小麦制品': {'面筋': {}, '面包': {}, '面皮': {}, '面包糠': {}, '油条': {}, '包子': {}, '饺子': {}, '虾饺': {}, '水饺': {}, '煎饺': {}, '锅贴': {}}}, '稻米': {'大米': {'糯米': {}}, '米饭、米粥等': {'米饭': {}, '寿司': {}}, '米粉': {}, '其他稻米制品': {'爆米花': {}, '年糕': {}, '河粉': {}, '糍粑': {}, '麻球': {}}, '米线': {}, '黑米': {}}, '玉米': {'玉米': {'芝士玉米': {}}, '玉米面、玉米粒等': {'玉米粒': {}}, '其他玉米制品': {}}, '大麦': {'大麦面粉': {}, '大麦制品': {}}, '小米、黄米': {'小米、黄米': {}, '小米或黄米制品': {}}, '其他': {'高粱及制品': {}, '荞麦及制品': {}, '糜子及制品': {}, '莜麦及制品': {}, '薏米及制品': {'薏米': {}}, '其他': {'禾谷类': {}}, '谷麦制品': {}, '燕麦': {}}, '米': {}, '饼': {}, '面': {}}, '薯类、淀粉及制品': {'薯类': {'马铃薯': {'土豆片': {}, '土豆': {}, '土豆丝': {}, '土豆粉': {}}, '甘薯': {}, '木薯': {}, '红薯': {'地瓜': {}}, '紫薯': {}, '香芋': {}, '薯类制品': {'芋圆': {}, '薯条': {}, '薯片': {}}}, '淀粉类': {'食用淀粉': {}, '淀粉制品': {'粉丝': {}, '粉条': {}, '藕粉': {}, '西谷米': {}, '粉皮': {}, '宽粉': {}, '粉': {}, '凉粉': {}}}}, '干豆类及制品': {'大豆':
# ...

# %%
origin_tree = ORIGIN_INFOS['食材树']

# %%
origin_big_class = set()
for key in origin_tree:
    origin_big_class.add(key)

# %%
print(len(origin_big_class))
# Out:
# 19

# %%
print(origin_big_class)
# Out:
# {'畜肉类及制品', '薯类、淀粉及制品', '菌藻类', '水产类 ', '其他', '乳类及制品', '坚果、种子类', '调味品类', '饮料和冷饮类', '蔬菜类及制品', '禽肉类及制品 ', '油脂类', '休闲食品', '速食食品', '水果类及制品', '蛋类及制品', '谷类及制品', '干豆类及制品', '含酒精饮料'}
